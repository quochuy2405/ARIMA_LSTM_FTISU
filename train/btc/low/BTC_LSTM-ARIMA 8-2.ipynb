# %% [markdown]
# ## 1. Quá trình dự báo trên mô hình ARIMA

# %% [markdown]
# # Thêm thư viện

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pmdarima as pmd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA

from sklearn.metrics import mean_squared_error
from sklearn.utils import column_or_1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import load_model

# %% [markdown]
# # Nạp dữ liệu từ file csv

# %%
df = pd.read_csv('../../../data/clean/btc_low.csv')
df.pop('volume')
df.pop('high')
df.pop('open')
df.pop('close')
df.pop('adjclose')
df = df.reset_index()
df['formatted_date'] = pd.to_datetime(df['formatted_date']).values.astype(np.int64)
df.set_index("formatted_date",inplace=True)
df.pop('index')
df.pop('Unnamed: 0')
df_low = df['low'].values.reshape(-1, 1)

df
# Out:
#                               low
# formatted_date
# 1546300800000000000   3817.409424
# 1546387200000000000   3826.222900
# 1546473600000000000   3783.853760
# 1546560000000000000   3836.900146
# 1546646400000000000   3826.513184
# ...                           ...
# 1681948800000000000  27177.365234
# 1682035200000000000  27169.570312
# 1682121600000000000  27400.314453
# 1682208000000000000  27070.849609
# 1682294400000000000  27340.068359
#
# [1575 rows x 1 columns]

# %% [markdown]
# # Chuẩn hóa dữ liệu

# %%
arima_sc = StandardScaler()

df_scaled = df.copy()
df_scaled['low'] = arima_sc.fit_transform(df_low)
df_scaled
# Out:
#                           low
# formatted_date
# 1546300800000000000 -1.165594
# 1546387200000000000 -1.165057
# 1546473600000000000 -1.167638
# 1546560000000000000 -1.164406
# 1546646400000000000 -1.165039
# ...                       ...
# 1681948800000000000  0.257661
# 1682035200000000000  0.257186
# 1682121600000000000  0.271244
# 1682208000000000000  0.251171
# 1682294400000000000  0.267574
#
# [1575 rows x 1 columns]

# %% [markdown]
# # Vẽ đồ thị

# %%
# Thư viện vẽ đồ thị
formatter = ticker.StrMethodFormatter('${x:,.0f}')

title = 'Bitcoin Price'
ylabel = 'USD'
xlabel = 'Date'

ax = df['low'].plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %% [markdown]
# # Tách dữ liệu thành tập train và test

# %%
train, test = df_scaled[:(int)(len(df_scaled) * 1)], df_scaled[(int)(len(df_scaled) * 1):]
index_test = df_scaled.index[:(int)(len(df_scaled) * 1)]
print('train shape: ', train.shape)
print('test shape: ', test.shape)
# Out:
# train shape:  (1575, 1)
# test shape:  (0, 1)

# %% [markdown]
# # Hàm kiểm định chuỗi dừng

# %%
def adf_test(series, title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    # .dropna() handles differenced data
    result = adfuller(series.dropna(), autolag='AIC')

    labels = ['ADF test statistic', 'p-value',
              'Number of lags used', 'Number of observations']
    out = pd.Series(result[0:4], index=labels)

    for key, val in result[4].items():
        out[f'critical value ({key})'] = val

    # .to_string() removes the line "dtype: float64"
    print(out.to_string())

    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non stationary")

# %% [markdown]
# # Kiểm định tính dừng của chuỗi

# %%
adf_test(train['low'],'Bitcoin Price')
# Out:
# Augmented Dickey-Fuller Test: Bitcoin Price
# ADF test statistic          -1.611238
# p-value                      0.477326
# Number of lags used         24.000000
# Number of observations    1550.000000
# critical value (1%)         -3.434576
# critical value (5%)         -2.863406
# critical value (10%)        -2.567764
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non stationary

# %% [markdown]
# nhận thấy p-value > 0.05, do đó chuỗi không phải là chuỗi dừng

# %% [markdown]
# # Tính sai phân bậc 1 (d = 1) của chuỗi để kiểm định tính dừng

# %%
diff_1 = train.dropna().diff()
diff_1.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='formatted_date'>

# %% [markdown]
# # Kiểm định tính dừng của chuỗi tại sai phân bậc 1

# %%
adf_test(diff_1, 'Bitcoin Price First Difference')
# Out:
# Augmented Dickey-Fuller Test: Bitcoin Price First Difference
# ADF test statistic       -7.991471e+00
# p-value                   2.467883e-12
# Number of lags used       2.400000e+01
# Number of observations    1.549000e+03
# critical value (1%)      -3.434579e+00
# critical value (5%)      -2.863408e+00
# critical value (10%)     -2.567764e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# Nhận thấy p-value < 0.05, do đó chuỗi có tính dừng tại sai phân bậc 1

# %%
def ArimaModel(timeseriesarray):
    autoarima_model = pmd.auto_arima(timeseriesarray, 
                              test="adf",
                              seasonal=False,
                              trace=True)
    return autoarima_model

# %%
import pickle
arima_model = ArimaModel(train)
arima_model.summary()
with open("../../../models/low/arima_model.pkl", "wb") as f:
        pickle.dump(arima_model, f)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-4019.725, Time=1.22 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-4005.363, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-4003.374, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-4003.373, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-4007.079, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-4002.322, Time=0.70 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-3999.854, Time=0.38 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-4017.758, Time=1.46 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-4022.188, Time=1.59 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-4009.704, Time=0.46 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-4013.290, Time=1.60 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-4017.016, Time=1.80 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-4014.451, Time=1.49 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-4018.457, Time=1.93 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-4024.115, Time=0.77 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-4011.400, Time=0.45 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-4026.390, Time=0.59 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-4003.488, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-4001.561, Time=0.18 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-4024.419, Time=0.76 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-4003.091, Time=0.24 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=-4009.445, Time=0.37 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-4022.820, Time=1.19 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 17.951 seconds

# %% [markdown]
# # Dự đoán trên tập test

# %%
pred = arima_model.predict(len(train))
pred
# Out:
# 1575    0.265023
# 1576    0.268332
# 1577    0.265378
# 1578    0.267129
# 1579    0.266943
#           ...
# 3145    0.266634
# 3146    0.266634
# 3147    0.266634
# 3148    0.266634
# 3149    0.266634
# Length: 1575, dtype: float64

# %% [markdown]
# # Biến đổi giá trị dự đoán và thực tế về miền giá trị ban đầu

# %%
inv_test = arima_sc.inverse_transform(train.values.reshape(-1, 1))
inv_pred = arima_sc.inverse_transform(column_or_1d(pred).reshape(-1, 1))

# %% [markdown]
# # Vẽ đồ thị cho tập test và kết quả dự đoán

# %%
pred_series = pd.Series(pred, index=index_test)

plt.figure(figsize=(16, 9))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(inv_test, 'blue', label='Actual data')
plt.plot(inv_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Đánh giá mô hình

# %%
mae = mean_absolute_error(inv_test, inv_pred)
mape = mean_absolute_percentage_error(inv_test, inv_pred)
mse = mean_squared_error(inv_test, inv_pred)
rmse = np.sqrt(mse)
r2 = r2_score(inv_test, inv_pred)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 15172.20
# MAPE: 138.80%
# MSE: 288539833.05
# RMSE: 16986.46
# R2: -0.07

# %% [markdown]
# # Tạo một DataFrame là 'df_pred' để lưu kết quả dự đoán trên mô hình ARIMA

# %%
df_pred = pd.DataFrame(index=index_test)
df_pred['Actual'] = inv_test
df_pred['ARIMA'] = inv_pred
df_pred['Error'] = inv_test - inv_pred
df_pred
# Out:
#                            Actual         ARIMA         Error
# formatted_date
# 1546300800000000000   3817.409424  27298.201347 -23480.791923
# 1546387200000000000   3826.222900  27352.510791 -23526.287891
# 1546473600000000000   3783.853760  27304.023029 -23520.169269
# 1546560000000000000   3836.900146  27332.773056 -23495.872910
# 1546646400000000000   3826.513184  27329.712805 -23503.199622
# ...                           ...           ...           ...
# 1681948800000000000  27177.365234  27324.643626   -147.278392
# 1682035200000000000  27169.570312  27324.643626   -155.073314
# 1682121600000000000  27400.314453  27324.643626     75.670827
# 1682208000000000000  27070.849609  27324.643626   -253.794017
# 1682294400000000000  27340.068359  27324.643626     15.424733
#
# [1575 rows x 3 columns]

# %% [markdown]
# ## 2. Quá trình dự đoán trên mô hình LSTM

# %% [markdown]
# # Tạo thêm một DataFrame để tiến hành dự đoán sai số trên mô hình LSTM

# %%
df_lstm = df_pred.copy()
df_lstm
# Out:
#                            Actual         ARIMA         Error
# formatted_date
# 1546300800000000000   3817.409424  27298.201347 -23480.791923
# 1546387200000000000   3826.222900  27352.510791 -23526.287891
# 1546473600000000000   3783.853760  27304.023029 -23520.169269
# 1546560000000000000   3836.900146  27332.773056 -23495.872910
# 1546646400000000000   3826.513184  27329.712805 -23503.199622
# ...                           ...           ...           ...
# 1681948800000000000  27177.365234  27324.643626   -147.278392
# 1682035200000000000  27169.570312  27324.643626   -155.073314
# 1682121600000000000  27400.314453  27324.643626     75.670827
# 1682208000000000000  27070.849609  27324.643626   -253.794017
# 1682294400000000000  27340.068359  27324.643626     15.424733
#
# [1575 rows x 3 columns]

# %% [markdown]
# # Vẽ đồ thị thể hiện sai số

# %%
formatter = ticker.StrMethodFormatter('${x:,.0f}')

error = df_lstm[['Error']]
title = 'Residual from ARIMA model'
ylabel = 'USD'
xlabel = 'Date'

ax = error.plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %%
error = np.array(error)
error
# Out:
# array([[-2.34807919e+04],
#        [-2.35262879e+04],
#        [-2.35201693e+04],
#        ...,
#        [ 7.56708270e+01],
#        [-2.53794017e+02],
#        [ 1.54247333e+01]])

# %%
look_back = 3
x_total, y_total = [], []
for i in range(look_back, len(error)):
	x_total.append(error[i-look_back:i])
	y_total.append(error[i])
x_train = np.array(x_total[:len(error)])
y_train = np.array(y_total[:len(error)])

print("x_train",x_train.shape)
print("y_train",y_train.shape)
# Out:
# x_train (1572, 3, 1)
# y_train (1572, 1)

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit
300
# 50/50 [==============================] - 0s 3ms/step - loss: 1391360.5000
# Epoch 220/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1289612.5000
# Epoch 221/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1498436.5000
# Epoch 222/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1289545.8750
# Epoch 223/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1359291.8750
# Epoch 224/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1374236.3750
# Epoch 225/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1352262.0000
# Epoch 226/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1475116.2500
# Epoch 227/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1343109.0000
# Epoch 228/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1306445.3750
# Epoch 229/300
# 50/50 [==============================] - 0s 4ms/step - loss: 1295852.7500
# Epoch 230/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1257436.5000
# Epoch 231/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1391704.7500
# Epoch 232/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1269047.8750
# Epoch 233/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1233918.3750
# Epoch 234/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1279285.1250
# Epoch 235/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1277069.6250
# Epoch 236/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1264763.3750
# Epoch 237/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1250144.3750
# Epoch 238/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1301309.1250
# Epoch 239/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1309158.7500
# Epoch 240/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1279457.2500
# Epoch 241/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1302336.2500
# Epoch 242/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1283050.6250
# Epoch 243/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1276620.8750
# Epoch 244/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1288042.1250
# Epoch 245/300
# 50/50 [==============================] - 0s 4ms/step - loss: 1268844.2500
# Epoch 246/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1362419.7500
# Epoch 247/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1250481.3750
# Epoch 248/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1442800.0000
# Epoch 249/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1230104.7500
# Epoch 250/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1255106.6250
# Epoch 251/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1247449.1250
# Epoch 252/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1262512.8750
# Epoch 253/300
# 50/50 [==============================] - 0s 4ms/step - loss: 1260044.7500
# Epoch 254/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1301167.1250
# Epoch 255/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1343441.8750
# Epoch 256/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1273048.6250
# Epoch 257/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1309669.5000
# Epoch 258/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1289592.3750
# Epoch 259/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1234281.1250
# Epoch 260/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1330905.2500
# Epoch 261/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1342316.7500
# Epoch 262/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1280439.1250
# Epoch 263/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1262985.2500
# Epoch 264/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1428950.7500
# Epoch 265/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1278996.0000
# Epoch 266/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1387430.7500
# Epoch 267/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1248636.6250
# Epoch 268/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1217539.8750
# Epoch 269/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1286819.7500
# Epoch 270/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1292255.1250
# Epoch 271/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1243437.3750
# Epoch 272/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1235506.6250
# Epoch 273/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1206124.2500
# Epoch 274/300
# 50/50 [==============================] - 0s 4ms/step - loss: 1296720.5000
# Epoch 275/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1318488.6250
# Epoch 276/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1294482.1250
# Epoch 277/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1255178.3750
# Epoch 278/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1213197.1250
# Epoch 279/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1210442.1250
# Epoch 280/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1251439.6250
# Epoch 281/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1270870.2500
# Epoch 282/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1349498.2500
# Epoch 283/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1300841.0000
# Epoch 284/300
# 50/50 [==============================] - 0s 3ms/step - loss: 6321622.5000
# Epoch 285/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1409517.7500
# Epoch 286/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1419982.0000
# Epoch 287/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1403838.7500
# Epoch 288/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1348084.2500
# Epoch 289/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1327040.1250
# Epoch 290/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1332777.7500
# Epoch 291/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1326988.7500
# Epoch 292/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1298448.0000
# Epoch 293/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1304714.7500
# Epoch 294/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1270826.1250
# Epoch 295/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1306051.1250
# Epoch 296/300
# 50/50 [==============================] - 0s 4ms/step - loss: 1281449.2500
# Epoch 297/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1292558.1250
# Epoch 298/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1298214.0000
# Epoch 299/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1277232.1250
# Epoch 300/300
# 50/50 [==============================] - 0s 3ms/step - loss: 1272595.3750

# %%
model = load_model("../../../models/low/lstm.h5")
error_pred = model.predict(x_train)
error_pred
# Out:
# 50/50 [==============================] - 0s 1ms/step
# array([[-2.3346949e+04],
#        [-2.3321162e+04],
#        [-2.3335664e+04],
#        ...,
#        [ 9.0432556e+01],
#        [-2.4986089e+02],
#        [-1.1397557e+01]], dtype=float32)

# %%
df_lstm = df_lstm.copy().head(len(error_pred))
df_lstm['Error Prediction'] = error_pred
df_lstm
# Out:
#                            Actual         ARIMA         Error  \
# formatted_date
# 1546300800000000000   3817.409424  27298.201347 -23480.791923
# 1546387200000000000   3826.222900  27352.510791 -23526.287891
# 1546473600000000000   3783.853760  27304.023029 -23520.169269
# 1546560000000000000   3836.900146  27332.773056 -23495.872910
# 1546646400000000000   3826.513184  27329.712805 -23503.199622
# ...                           ...           ...           ...
# 1681689600000000000  29154.849609  27324.643626   1830.205983
# 1681776000000000000  28669.898438  27324.643626   1345.254811
# 1681862400000000000  28037.257812  27324.643626    712.614186
# 1681948800000000000  27177.365234  27324.643626   -147.278392
# 1682035200000000000  27169.570312  27324.643626   -155.073314
#
#                      Error Prediction
# formatted_date
# 1546300800000000000     -23346.949219
# 1546387200000000000     -23321.162109
# 1546473600000000000     -23335.664062
# 1546560000000000000     -23076.058594
# 1546646400000000000     -23197.982422
# ...                               ...
# 1681689600000000000        876.874146
# 1681776000000000000        483.944031
# 1681862400000000000         90.432556
# 1681948800000000000       -249.860886
# 1682035200000000000        -11.397557
#
# [1572 rows x 4 columns]

# %%
df_lstm['ARIMA_LSTM'] = df_lstm['ARIMA'] + df_lstm['Error Prediction']
df_lstm
# Out:
#                            Actual         ARIMA         Error  \
# formatted_date
# 1546300800000000000   3817.409424  27298.201347 -23480.791923
# 1546387200000000000   3826.222900  27352.510791 -23526.287891
# 1546473600000000000   3783.853760  27304.023029 -23520.169269
# 1546560000000000000   3836.900146  27332.773056 -23495.872910
# 1546646400000000000   3826.513184  27329.712805 -23503.199622
# ...                           ...           ...           ...
# 1681689600000000000  29154.849609  27324.643626   1830.205983
# 1681776000000000000  28669.898438  27324.643626   1345.254811
# 1681862400000000000  28037.257812  27324.643626    712.614186
# 1681948800000000000  27177.365234  27324.643626   -147.278392
# 1682035200000000000  27169.570312  27324.643626   -155.073314
#
#                      Error Prediction    ARIMA_LSTM
# formatted_date
# 1546300800000000000     -23346.949219   3951.252128
# 1546387200000000000     -23321.162109   4031.348682
# 1546473600000000000     -23335.664062   3968.358967
# 1546560000000000000     -23076.058594   4256.714462
# 1546646400000000000     -23197.982422   4131.730383
# ...                               ...           ...
# 1681689600000000000        876.874146  28201.517772
# 1681776000000000000        483.944031  27808.587657
# 1681862400000000000         90.432556  27415.076182
# 1681948800000000000       -249.860886  27074.782740
# 1682035200000000000        -11.397557  27313.246069
#
# [1572 rows x 5 columns]

# %% [markdown]
# # Vẽ đồ thị

# %%
plt.figure(figsize=(16, 9))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_lstm['Actual'], 'blue', label='Actual data')
plt.plot(df_lstm['ARIMA_LSTM'], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Đánh giá mô hình

# %%
mae = mean_absolute_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
mape = mean_absolute_percentage_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
mse = mean_squared_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
rmse = np.sqrt(mse)
r2 = r2_score(df_lstm.Actual, df_lstm.ARIMA_LSTM)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 868.97
# MAPE: 4.04%
# MSE: 2080320.86
# RMSE: 1442.33
# R2: 0.99
